# %%
#pip install --upgrade pynytimes

# %%
import pandas as pd 
import numpy as np
from datetime import date, datetime
import datetime
from pynytimes import NYTAPI
import warnings

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# Ignore warnings
warnings.filterwarnings("ignore")

# %%
api_key = "5USaj8jYA7aPcY2HVwsmEZdmsBCVSUQS"

# %%
# initialze with api key 
nyt = NYTAPI(api_key,parse_dates=True)

# %%
biz_sent = nyt.article_search(
    query="stock", #currently looking up stock as search term
    results = 2000, 
    #need to add time component
    dates={
        "start": datetime.datetime(2014,0o1,0o1 ),
        "end": datetime.datetime(2015, 0o1, 0o1)}, # need to break up dates when running large amount in order to not pull repeat articles from earlier dates
    options = {
        "sort": "relevance",
        "sources": [
            "New York Times",
            "AP",
            "Reuters",
            "International Herald Tribune"
        ],
        "news_desk": [
            "Business"
        ],
        "type_of_material": [
            "News Analysis", "Summary", "Text" ,"News", "List", "Interview", "Article"
        ]
    }
)

# %%
df = pd.DataFrame(biz_sent)

# %%
df.columns
# Out:
# Index(['abstract', 'web_url', 'snippet', 'lead_paragraph', 'source',
#        'multimedia', 'headline', 'keywords', 'pub_date', 'document_type',
#        'news_desk', 'section_name', 'byline', 'type_of_material', '_id',
#        'word_count', 'uri', 'print_section', 'print_page', 'subsection_name'],
#       dtype='object')

# %%
df= df[['abstract','snippet','lead_paragraph','web_url','pub_date','section_name','headline']]

# %%
df.shape
# Out:
# (2000, 7)

# %%
df.pub_date
# Out:
# 0      2014-12-31 23:06:59+00:00
# 1      2014-12-10 12:56:45+00:00
# 2      2014-12-24 14:21:58+00:00
# 3      2014-12-18 10:07:49+00:00
# 4      2014-11-13 11:06:58+00:00
# 5      2014-11-17 16:49:55+00:00
# 6      2014-11-17 09:14:20+00:00
# 7      2014-11-14 17:16:39+00:00
# 8      2014-11-10 20:53:33+00:00
# 9      2014-11-10 19:05:36+00:00
# 10     2014-11-07 17:09:29+00:00
# 11     2014-11-06 20:27:57+00:00
# 12     2014-11-05 19:33:59+00:00
# 13     2014-11-03 20:41:59+00:00
# 14     2014-10-31 23:21:53+00:00
# 15     2014-10-27 18:00:39+00:00
# 16     2014-10-27 15:18:30+00:00
# 17     2014-10-24 15:29:30+00:00
# 18     2014-10-20 19:12:49+00:00
# 19     2014-10-20 16:02:23+00:00
# 20     2014-10-17 18:16:46+00:00
# 21     2014-10-16 13:51:44+00:00
# 22     2014-10-15 18:32:06+00:00
# 23     2014-10-15 15:10:25+00:00
# 24     2014-10-13 19:38:22+00:00
# 25     2014-10-13 19:28:42+00:00
# 26     2014-10-13 15:36:42+00:00
# 27     2014-10-10 22:26:24+00:00
# ...

# %%
biz_sent1 = nyt.article_search(
    query="stock", #currently looking up stock as search term
    results = 2000, 
    #need to add time component
    dates={
        "start": datetime.datetime(2015,0o1,0o1 ),
        "end": datetime.datetime(2016, 0o1, 0o1)}, # need to break up dates when running large amount in order to not pull repeat articles from earlier dates
    options = {
        "sort": "relevance",
        "sources": [
            "New York Times",
            "AP",
            "Reuters",
            "International Herald Tribune"
        ],
        "news_desk": [
            "Business"
        ],
        "type_of_material": [
            "News Analysis", "Summary", "Text" ,"News", "List", "Interview", "Article"
        ]
    }
)

# %%
df1 = pd.DataFrame(biz_sent1)

# %%
df1= df1[['abstract','snippet','lead_paragraph','web_url','pub_date','section_name']]

# %%
df1.shape
# Out:
# (2000, 6)

# %%
df1.pub_date
# Out:
# 0      2015-12-16 20:17:27+00:00
# 1      2015-12-31 23:49:50+00:00
# 2      2015-12-12 01:19:15+00:00
# 3      2015-12-09 21:51:52+00:00
# 4      2015-12-03 19:33:06+00:00
# 5      2015-11-23 01:31:54+00:00
# 6      2015-11-12 11:59:36+00:00
# 7      2015-11-11 14:03:16+00:00
# 8      2015-11-10 09:15:26+00:00
# 9      2015-10-27 09:17:22+00:00
# 10     2015-10-21 23:13:55+00:00
# 11     2015-10-21 16:01:52+00:00
# 12     2015-10-21 00:20:10+00:00
# 13     2015-10-14 09:25:24+00:00
# 14     2015-10-13 07:30:03+00:00
# 15     2015-10-08 18:47:13+00:00
# 16     2015-09-29 07:35:30+00:00
# 17     2015-10-02 09:26:14+00:00
# 18     2015-10-01 09:03:51+00:00
# 19     2015-09-29 00:53:25+00:00
# 20     2015-09-15 08:25:14+00:00
# 21     2015-09-17 14:47:52+00:00
# 22     2015-09-02 03:14:29+00:00
# 23     2015-09-04 09:44:33+00:00
# 24     2015-09-03 11:29:49+00:00
# 25     2015-08-24 15:48:31+00:00
# 26     2015-09-01 00:23:09+00:00
# 27     2015-08-25 03:22:04+00:00
# ...

# %%
biz_sent2 = nyt.article_search(
    query="stock", #currently looking up stock as search term
    results = 2000, 
    #need to add time component
    dates={
        "start": datetime.datetime(2016,0o1,0o1 ),
        "end": datetime.datetime(2017, 0o1, 0o1)}, # need to break up dates when running large amount in order to not pull repeat articles from earlier dates
    options = {
        "sort": "relevance",
        "sources": [
            "New York Times",
            "AP",
            "Reuters",
            "International Herald Tribune"
        ],
        "news_desk": [
            "Business"
        ],
        "type_of_material": [
            "News Analysis", "Summary", "Text" ,"News", "List", "Interview", "Article"
        ]
    }
)

# %%
df2 = pd.DataFrame(biz_sent2)

# %%
df2= df2[['abstract','snippet','lead_paragraph','web_url','pub_date','section_name']]

# %%
df2.shape
# Out:
# (2000, 6)

# %%
df2.pub_date
# Out:
# 0      2016-12-20 10:22:58+00:00
# 1      2016-12-25 21:41:01+00:00
# 2      2016-12-23 20:56:41+00:00
# 3      2016-12-15 16:39:37+00:00
# 4      2016-12-02 10:33:58+00:00
# 5      2016-11-25 21:06:53+00:00
# 6      2016-11-08 19:06:43+00:00
# 7      2016-10-28 10:17:18+00:00
# 8      2016-10-27 10:06:09+00:00
# 9      2016-10-27 05:34:56+00:00
# 10     2016-09-28 15:48:12+00:00
# 11     2016-09-26 20:37:36+00:00
# 12     2016-08-12 09:41:33+00:00
# 13     2016-08-11 01:24:43+00:00
# 14     2016-07-26 16:53:03+00:00
# 15     2016-07-11 15:12:52+00:00
# 16     2016-07-04 14:50:41+00:00
# 17     2016-06-09 07:30:21+00:00
# 18     2006-04-29 04:00:00+00:00
# 19     2010-07-05 05:15:25+00:00
# 20     2007-05-03 04:00:00+00:00
# 21     2007-09-28 04:00:00+00:00
# 22     2007-02-06 05:00:00+00:00
# 23     2009-05-08 13:46:16+00:00
# 24     2016-06-28 15:25:13+00:00
# 25     2008-10-31 20:30:24+00:00
# 26     2007-10-26 01:45:15+00:00
# 27     2007-06-04 20:05:20+00:00
# ...

# %%
biz_sent3 = nyt.article_search(
    query="stock", #currently looking up stock as search term
    results = 2000, 
    #need to add time component
    dates={
        "start": datetime.datetime(2017,0o1,0o1 ),
        "end": datetime.datetime(2018, 0o1, 0o1)}, # need to break up dates when running large amount in order to not pull repeat articles from earlier dates
    options = {
        "sort": "relevance",
        "sources": [
            "New York Times",
            "AP",
            "Reuters",
            "International Herald Tribune"
        ],
        "news_desk": [
            "Business"
        ],
        "type_of_material": [
            "News Analysis", "Summary", "Text" ,"News", "List", "Interview", "Article"
        ]
    }
)

# %%
df3 = pd.DataFrame(biz_sent3)

# %%
df3= df3[['abstract','snippet','lead_paragraph','web_url','pub_date','section_name']]

# %%
df3.shape
# Out:
# (2000, 6)

# %%
df3.pub_date
# Out:
# 0      2017-11-29 08:42:16+00:00
# 1      2017-11-30 15:13:33+00:00
# 2      2017-11-14 12:44:38+00:00
# 3      2017-11-05 22:23:35+00:00
# 4      2017-11-04 20:10:31+00:00
# 5      2017-11-02 18:01:30+00:00
# 6      2017-10-26 17:03:33+00:00
# 7      2017-10-23 20:04:23+00:00
# 8      2017-10-11 10:29:08+00:00
# 9      2017-10-10 14:28:38+00:00
# 10     2017-10-05 11:08:39+00:00
# 11     2017-09-27 18:06:06+00:00
# 12     2017-09-15 20:27:39+00:00
# 13     2017-09-14 10:44:53+00:00
# 14     2017-09-05 22:12:26+00:00
# 15     2017-08-10 17:08:04+00:00
# 16     2017-08-10 23:56:24+00:00
# 17     2017-08-09 19:08:15+00:00
# 18     2017-08-02 00:59:18+00:00
# 19     2017-07-31 23:58:35+00:00
# 20     2017-07-13 16:37:51+00:00
# 21     2006-04-29 04:00:00+00:00
# 22     2010-07-05 05:15:25+00:00
# 23     2007-05-03 04:00:00+00:00
# 24     2017-06-29 15:27:46+00:00
# 25     2007-09-28 04:00:00+00:00
# 26     2007-02-06 05:00:00+00:00
# 27     2009-05-08 13:46:16+00:00
# ...

# %%
# Prepare data frames to be combined
frames = [df, df1, df2, df3]

# %%
# Combine all data frames
mix = pd.concat(frames)

# %%
# Orgainize dataframe in order of date
mix.sort_values(by='pub_date', inplace=True)

# %%
# Get rid of all publications earlier than 2014
mix.query("pub_date.dt.year > 2013", inplace=True)

# %%
#Set the 'pub_date' column as the index
mix.set_index('pub_date', inplace = True)

# %%
mix.head()
# Out:
#                                                                     abstract  \
# pub_date
# 2014-01-10 02:56:53+00:00  The trial, which was cut short, showed that In...
# 2014-01-10 02:56:53+00:00  The trial, which was cut short, showed that In...
# 2014-01-10 02:56:53+00:00  The trial, which was cut short, showed that In...
# 2014-01-10 02:56:53+00:00  The trial, which was cut short, showed that In...
# 2014-01-10 02:56:53+00:00  The trial, which was cut short, showed that In...
#
#                                                                      snippet  \
# pub_date
# 2014-01-10 02:56:53+00:00  The trial, which was cut short, showed that In...
# 2014-01-10 02:56:53+00:00  The trial, which was cut short, showed that In...
# 2014-01-10 02:56:53+00:00  The trial, which was cut short, showed that In...
# 2014-01-10 02:56:53+00:00  The trial, which was cut short, showed that In...
# 2014-01-10 02:56:53+00:00  The trial, which was cut short, showed that In...
#
# ...

# %%
mix.shape
# Out:
# (1097, 6)

# %%
mix = mix.drop_duplicates(subset=['abstract','snippet','lead_paragraph','web_url','section_name'])

# %%
mix.shape
# Out:
# (500, 6)

# %%
mix.isnull().sum()
# Out:
# abstract            0
# snippet             0
# lead_paragraph      0
# web_url             0
# section_name        0
# headline          364
# dtype: int64

# %%
mix.head()
# Out:
#                                                                     abstract  \
# pub_date
# 2014-01-10 02:56:53+00:00  The trial, which was cut short, showed that In...
# 2014-01-31 16:49:26+00:00  Motif, an investment site, tries to help small...
# 2014-02-05 02:15:23+00:00  The compensation for Mr. Schmidt, Google’s cha...
# 2014-02-05 22:00:19+00:00  The microblogging company said revenue for the...
# 2014-02-10 02:03:40+00:00  Sheryl Sandberg’s nonprofit organization is pa...
#
#                                                                      snippet  \
# pub_date
# 2014-01-10 02:56:53+00:00  The trial, which was cut short, showed that In...
# 2014-01-31 16:49:26+00:00  Motif, an investment site, tries to help small...
# 2014-02-05 02:15:23+00:00  The compensation for Mr. Schmidt, Google’s cha...
# 2014-02-05 22:00:19+00:00  The microblogging company said revenue for the...
# 2014-02-10 02:03:40+00:00  Sheryl Sandberg’s nonprofit organization is pa...
#
# ...

# %%
mix.to_csv('./data/14_17_data.csv')
