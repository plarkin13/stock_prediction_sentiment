# %%
from datetime import date, datetime
from pynytimes import NYTAPI


# Make sure to set parse dates to True so that the dates
# are parsed into datetime.datetime or datetime.date objects
nyt = NYTAPI(
    key="t8vriKxFjaET2Qo7jSVKTsBYVXSeGw0h",  # Get your API Key at https://developer.nytimes.com
    parse_dates=True,
)


# You can optionally define the dates between which you want the articles to be
biz_sent = nyt.article_search(
    query="stock", #currently looking up stock as search term
    results = 5, #pulling 5 results
    #need to add time component
    dates={"start": date(2011, 1, 1), "end": date(2013, 12, 31)}, # need to break up dates when running large amount in order to not pull repeat articles from earlier dates
    options = {
        "sort": "oldest",
        "sources": [
            "New York Times",
            "AP",
            "Reuters",
            "International Herald Tribune"
        ],
        "news_desk": [
            "Business"
        ],
        "type_of_material": [
            "News Analysis", "Summary", "Text" ,"News", "List", "Interview", "Article"
        ]
    }
)

# %%
biz_sent
# Out:
# [{'abstract': "The American Express Company will acquire Shearson Loeb Rhoades, Wall Street's second-largest brokerage firm, for about $915 million in stock, the two companies announced yesterday.",
#   'web_url': 'https://www.nytimes.com/1981/04/22/business/american-express-to-buy-shearson-as-takeovers-transform-wall-st.html',
#   'snippet': "The American Express Company will acquire Shearson Loeb Rhoades, Wall Street's second-largest brokerage firm, for about $915 million in stock, the two companies announced yesterday.",
#   'lead_paragraph': "The American Express Company will acquire Shearson Loeb Rhoades, Wall Street's second-largest brokerage firm, for about $915 million in stock, the two companies announced yesterday.",
#   'source': 'The New York Times',
#   'multimedia': [],
#   'headline': {'main': 'American Express to Buy Shearson as Takeovers Transform Wall St.',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'American Express to Buy Shearson as Takeovers Transform Wall St.',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [],
#   'pub_date': datetime.datetime(1981, 4, 22, 5, 0, tzinfo=datetime.timezone.utc),
#   'document_type': 'article',
#   'news_desk': 'Business',
#   'section_name': 'Business Day',
#   'byline': {'original': 'By Robert J. Cole',
#    'person': [{'firstname': 'Robert',
#      'middlename': 'J.',
#      'lastname': 'Cole',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/1524299e-31d7-5dbc-9505-e3974ee9da7f',
#   'word_count': 2089,
#   'uri': 'nyt://article/1524299e-31d7-5dbc-9505-e3974ee9da7f'},
#  {'abstract': 'The Allied Corporation and the Bendix Corporation announced yesterday that they had agreed to merge, making Allied the fourth entry in one of the most bizarre takeover battles in American corporate history.',
#   'web_url': 'https://www.nytimes.com/1982/09/23/business/bendix-and-allied-agree-to-a-merger.html',
#   'snippet': 'The Allied Corporation and the Bendix Corporation announced yesterday that they had agreed to merge, making Allied the fourth entry in one of the most bizarre takeover battles in American corporate history.',
#   'lead_paragraph': 'The Allied Corporation and the Bendix Corporation announced yesterday that they had agreed to merge, making Allied the fourth entry in one of the most bizarre takeover battles in American corporate history.',
#   'source': 'The New York Times',
#   'multimedia': [],
#   'headline': {'main': 'Bendix and Allied Agree to a Merger',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Bendix and Allied Agree to a Merger',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [],
#   'pub_date': datetime.datetime(1982, 9, 23, 5, 0, tzinfo=datetime.timezone.utc),
#   'document_type': 'article',
#   'news_desk': 'Business',
#   'section_name': 'Business Day',
#   'byline': {'original': 'By Robert J. Cole',
#    'person': [{'firstname': 'Robert',
#      'middlename': 'J.',
#      'lastname': 'Cole',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/ccc97862-df4c-59d2-a731-ca4fb35d6ab5',
#   'word_count': 3633,
#   'uri': 'nyt://article/ccc97862-df4c-59d2-a731-ca4fb35d6ab5'},
#  {'abstract': "In a move that stunned Wall Street, the Diamond Shamrock Corporation of Texas, one of the nation's lesser-known oil companies, yesterday called off a $3.3 billion merger with the Occidental Petroleum Company only hours after the companies' managements had agreed on the deal.",
#   'web_url': 'https://www.nytimes.com/1985/01/08/business/wall-street-stunned-as-shamrock-cancels-giant-occidental-merger.html',
#   'snippet': "In a move that stunned Wall Street, the Diamond Shamrock Corporation of Texas, one of the nation's lesser-known oil companies, yesterday called off a $3.3 billion merger with the Occidental Petroleum Company only hours after the companies' managem...",
#   'lead_paragraph': "In a move that stunned Wall Street, the Diamond Shamrock Corporation of Texas, one of the nation's lesser-known oil companies, yesterday called off a $3.3 billion merger with the Occidental Petroleum Company only hours after the companies' managements had agreed on the deal.",
#   'source': 'The New York Times',
#   'multimedia': [],
#   'headline': {'main': 'Wall Street Stunned as Shamrock Cancels Giant Occidental Merger',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Wall Street Stunned as Shamrock Cancels Giant Occidental Merger',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [],
#   'pub_date': datetime.datetime(1985, 1, 8, 5, 0, tzinfo=datetime.timezone.utc),
#   'document_type': 'article',
#   'news_desk': 'Business',
#   'section_name': 'Business Day',
#   'byline': {'original': 'By Robert J. Cole',
#    'person': [{'firstname': 'Robert',
#      'middlename': 'J.',
#      'lastname': 'Cole',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/42b2a200-674e-557d-b30d-3735cc5126d9',
#   'word_count': 2283,
#   'uri': 'nyt://article/42b2a200-674e-557d-b30d-3735cc5126d9'},
#  {'abstract': "CBS Inc., moving aggressively to thwart Ted Turner's takeover offer, announced yesterday that it would spend nearly $1 billion to repurchase up to 21 percent of its stock.",
#   'web_url': 'https://www.nytimes.com/1985/07/04/business/cbs-trying-to-block-turner-bid-to-buy-1-billion-of-its-own-stock.html',
#   'snippet': "CBS Inc., moving aggressively to thwart Ted Turner's takeover offer, announced yesterday that it would spend nearly $1 billion to repurchase up to 21 percent of its stock.",
#   'lead_paragraph': "CBS Inc., moving aggressively to thwart Ted Turner's takeover offer, announced yesterday that it would spend nearly $1 billion to repurchase up to 21 percent of its stock.",
#   'source': 'The New York Times',
#   'multimedia': [],
#   'headline': {'main': 'CBS, Trying to Block Turner Bid, to Buy $1 Billion of Its Own Stock',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'CBS, Trying to Block Turner Bid, to Buy $1 Billion of Its Own Stock',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [],
#   'pub_date': datetime.datetime(1985, 7, 4, 5, 0, tzinfo=datetime.timezone.utc),
#   'document_type': 'article',
#   'news_desk': 'Business',
#   'section_name': 'Business Day',
#   'byline': {'original': 'By Geraldine Fabrikant',
#    'person': [{'firstname': 'Geraldine',
#      'middlename': None,
#      'lastname': 'Fabrikant',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/e2b37666-52ae-553b-96e9-f199f552849a',
#   'word_count': 2383,
#   'uri': 'nyt://article/e2b37666-52ae-553b-96e9-f199f552849a'},
#  {'abstract': 'Madison Avenue, the symbolic if not actual home of the advertising world, is going through its most dramatic change since the business began a century ago.',
#   'web_url': 'https://www.nytimes.com/1986/05/13/business/ad-agency-mergers-changing-the-business.html',
#   'snippet': 'Madison Avenue, the symbolic if not actual home of the advertising world, is going through its most dramatic change since the business began a century ago.',
#   'lead_paragraph': 'Madison Avenue, the symbolic if not actual home of the advertising world, is going through its most dramatic change since the business began a century ago.',
#   'source': 'The New York Times',
#   'multimedia': [],
#   'headline': {'main': 'Ad Agency Mergers Changing the Business',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Ad Agency Mergers Changing the Business',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [],
#   'pub_date': datetime.datetime(1986, 5, 13, 5, 0, tzinfo=datetime.timezone.utc),
#   'document_type': 'article',
#   'news_desk': 'Business',
#   'section_name': 'Business Day',
#   'byline': {'original': 'By Richard W. Stevenson',
#    'person': [{'firstname': 'Richard',
#      'middlename': 'W.',
#      'lastname': 'Stevenson',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/6364b695-91bd-5c77-a36c-2e4e721b7d1a',
#   'word_count': 2575,
#   'uri': 'nyt://article/6364b695-91bd-5c77-a36c-2e4e721b7d1a'},
#  {'abstract': 'Big business in America is overhauling itself and its operations faster than at any time since World War II.',
#   'web_url': 'https://www.nytimes.com/1986/12/19/business/1986s-legacy-tumultuous-era-for-big-business.html',
#   'snippet': 'Big business in America is overhauling itself and its operations faster than at any time since World War II.',
#   'lead_paragraph': 'Big business in America is overhauling itself and its operations faster than at any time since World War II.',
#   'source': 'The New York Times',
#   'multimedia': [],
#   'headline': {'main': "1986's Legacy: Tumultuous Era for Big Business",
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': "1986's Legacy: Tumultuous Era for Big Business",
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [],
#   'pub_date': datetime.datetime(1986, 12, 19, 5, 0, tzinfo=datetime.timezone.utc),
#   'document_type': 'article',
#   'news_desk': 'Business',
#   'section_name': 'Business Day',
#   'byline': {'original': 'By Leslie Wayne',
#    'person': [{'firstname': 'Leslie',
#      'middlename': None,
#      'lastname': 'Wayne',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/aec616ab-dc49-59f8-94e1-5c4dcaf29148',
#   'word_count': 2783,
#   'uri': 'nyt://article/aec616ab-dc49-59f8-94e1-5c4dcaf29148'},
#  {'abstract': 'Big business in America is overhauling itself and its operations faster than at any time since World War II.',
#   'web_url': 'https://www.nytimes.com/1986/12/29/business/1986s-legacy-tumultuous-era-for-big-business.html',
#   'snippet': 'Big business in America is overhauling itself and its operations faster than at any time since World War II.',
#   'lead_paragraph': 'Big business in America is overhauling itself and its operations faster than at any time since World War II.',
#   'source': 'The New York Times',
#   'multimedia': [],
#   'headline': {'main': "1986's Legacy: Tumultuous Era for Big Business",
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': "1986's Legacy: Tumultuous Era for Big Business",
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [],
#   'pub_date': datetime.datetime(1986, 12, 29, 5, 0, tzinfo=datetime.timezone.utc),
#   'document_type': 'article',
#   'news_desk': 'Business',
#   'section_name': 'Business Day',
#   'byline': {'original': 'By Leslie Wayne',
#    'person': [{'firstname': 'Leslie',
#      'middlename': None,
#      'lastname': 'Wayne',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/e4868bf8-2f0d-58ee-8fd5-1a7b994eabdc',
#   'word_count': 2783,
#   'uri': 'nyt://article/e4868bf8-2f0d-58ee-8fd5-1a7b994eabdc'},
#  {'abstract': 'Few financiers love trading assets more than Kirk Kerkorian.',
#   'web_url': 'https://www.nytimes.com/1988/05/31/business/for-mgmua-bidders-are-scarce.html',
#   'snippet': 'Few financiers love trading assets more than Kirk Kerkorian.',
#   'lead_paragraph': 'Few financiers love trading assets more than Kirk Kerkorian.',
#   'source': 'The New York Times',
#   'multimedia': [],
#   'headline': {'main': 'For MGM/UA, Bidders Are Scarce',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'For MGM/UA, Bidders Are Scarce',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [],
#   'pub_date': datetime.datetime(1988, 5, 31, 5, 0, tzinfo=datetime.timezone.utc),
#   'document_type': 'article',
#   'news_desk': 'Business',
#   'section_name': 'Business Day',
#   'byline': {'original': 'By Geraldine Fabrikant',
#    'person': [{'firstname': 'Geraldine',
#      'middlename': None,
#      'lastname': 'Fabrikant',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/939c6845-2c66-50e0-8870-b9dd7dd56b65',
#   'word_count': 2913,
#   'uri': 'nyt://article/939c6845-2c66-50e0-8870-b9dd7dd56b65'},
#  {'abstract': 'Sanford I. Weill, who created the brokerage firm now known as Shearson Lehman Hutton, re-emerged yesterday as a Wall Street powerhouse with the announcement that he and Gerald Tsai Jr., another leading financier, would merge their current companies in a $1.65 billion deal.',
#   'web_url': 'https://www.nytimes.com/1988/08/30/business/2-leading-financiers-will-merge-companies-in-165-billion-deal.html',
#   'snippet': 'Sanford I. Weill, who created the brokerage firm now known as Shearson Lehman Hutton, re-emerged yesterday as a Wall Street powerhouse with the announcement that he and Gerald Tsai Jr., another leading financier, would merge their current companie...',
#   'lead_paragraph': 'Sanford I. Weill, who created the brokerage firm now known as Shearson Lehman Hutton, re-emerged yesterday as a Wall Street powerhouse with the announcement that he and Gerald Tsai Jr., another leading financier, would merge their current companies in a $1.65 billion deal.',
#   'source': 'The New York Times',
#   'multimedia': [],
#   'headline': {'main': '2 Leading Financiers Will Merge Companies in $1.65 Billion Deal',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': '2 Leading Financiers Will Merge Companies in $1.65 Billion Deal',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [],
#   'pub_date': datetime.datetime(1988, 8, 30, 5, 0, tzinfo=datetime.timezone.utc),
#   'document_type': 'article',
#   'news_desk': 'Business',
#   'section_name': 'Business Day',
#   'byline': {'original': 'By Robert J. Cole',
#    'person': [{'firstname': 'Robert',
#      'middlename': 'J.',
#      'lastname': 'Cole',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/c11414b0-c1ca-590d-a84f-4ec5941562fd',
#   'word_count': 3029,
#   'uri': 'nyt://article/c11414b0-c1ca-590d-a84f-4ec5941562fd'},
#  {'abstract': 'In one of the roughest, most confusing and dramatic finales to a takeover battle, the small but powerful buyout firm of Kohlberg, Kravis, Roberts & Company claimed victory late last night in the contest for RJR Nabisco Inc. with a staggering offer of $24.88 billion, the largest sum ever paid for a corporation.',
#   'web_url': 'https://www.nytimes.com/1988/12/01/business/rjr-nabisco-suitor-claims-2488-billion-victory.html',
#   'snippet': 'In one of the roughest, most confusing and dramatic finales to a takeover battle, the small but powerful buyout firm of Kohlberg, Kravis, Roberts & Company claimed victory late last night in the contest for RJR Nabisco Inc. with a staggering offer...',
#   'lead_paragraph': 'In one of the roughest, most confusing and dramatic finales to a takeover battle, the small but powerful buyout firm of Kohlberg, Kravis, Roberts & Company claimed victory late last night in the contest for RJR Nabisco Inc. with a staggering offer of $24.88 billion, the largest sum ever paid for a corporation.',
#   'source': 'The New York Times',
#   'multimedia': [],
#   'headline': {'main': 'RJR Nabisco Suitor Claims $24.88 Billion Victory',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'RJR Nabisco Suitor Claims $24.88 Billion Victory',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [],
#   'pub_date': datetime.datetime(1988, 12, 1, 5, 0, tzinfo=datetime.timezone.utc),
#   'document_type': 'article',
#   'news_desk': 'Business',
#   'section_name': 'Business Day',
#   'byline': {'original': 'By James Sterngold',
#    'person': [{'firstname': 'James',
#      'middlename': None,
#      'lastname': 'Sterngold',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/56d5947c-0336-5591-836d-4f0b6241b236',
#   'word_count': 2913,
#   'uri': 'nyt://article/56d5947c-0336-5591-836d-4f0b6241b236'}]

# %%
import pandas as pd
#create dataframe out of retrieved text
