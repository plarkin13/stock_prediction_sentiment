# %%
import numpy as np
import pandas as pd 
import datetime
from pynytimes import NYTAPI
#pip install --upgrade pynytimes


# Make sure to set parse dates to True so that the dates
# are parsed into datetime.datetime or datetime.date objects
nyt = NYTAPI(
    key="t8vriKxFjaET2Qo7jSVKTsBYVXSeGw0h",  # Get your API Key at https://developer.nytimes.com
    parse_dates=True,
)


def nyt_searcher(n_results,start_date,):
    'number of results,start date (in datetime.date format)'
    # add way to do more then one if n_results >2010 
    # number of searches with 2k results each 
    num_2k_searches = n_results//2000
    #number of searches left after doing all 2k searches
    num_last_search = n_results%2000
    # initial starting date 
    last_date = start_date
    # initialize empty list to store results 
    results =[]
    #do num_2k_searches
    for i in range(num_2k_searches):
        articles = nyt.article_search(
            results= 2000, # 2k searchs each run 
            dates= {"end":last_date}, # gets updated each iteration
            options = {"sort": "relevance",
            "sources": [
            "New York Times",
            "AP",
            "Reuters",
            "International Herald Tribune"
            ],
            "news_desk": [
            "Business"
            ],
            "type_of_material": [
                "News Analysis", "Summary", "Text" ,"News", "List", "Interview", "Article"
            ]
        }
)
        results.append(articles) # add articles from this run to results list
        articles_df = pd.DataFrame(articles) # prob better way to do this but this works for now
        num_articles= len(articles) 
        last_date = articles_df['pub_date'][num_articles] # assuming they come in order...
        last_date= datetime.datetime.date(last_date) # convert to datetime.date for usage in next iteration
    # run last search for num_last_search results if greater then 0 
    if num_last_search !=0: 
        last_articles = nyt.article_search(
                results= num_last_search,
                dates= {"end":last_date},
                options = {"sort": "relevance",
                "sources": [
                "New York Times",
                "AP",
                "Reuters",
                "International Herald Tribune"
                ],
                "news_desk": [
                "Business"
                ],
                "type_of_material": [
                    "News Analysis", "Summary", "Text" ,"News", "List", "Interview", "Article"
                ]
            }
    ) 
        # add last_articles to results list 
        results.append(last_articles)
    #BELOW SECTION MAY NEED WORK ???
    flatten_results = [val for sublist in results for val in sublist] #results is returning a double listed dictionary value and this reduces it to a single list that we can create a dataframe out of
    
    # if less 2000 posts in search results
    if len(results)==1:
        results_df= pd.DataFrame(flatten_results)
    else: 
        #make list of dictionaries into dataframe 
        results_df = pd.concat(results,sort=False)
        results_df= pd.DataFrame(flatten_results)
    #drop duplicates 
    #results_df.drop_duplicates(inplace=True)
    return results_df

# %%
# testing function 
test_df_12 = nyt_searcher(100,datetime.date(2011, 1, 4))
# Out:
# /Users/plarkin/opt/anaconda3/lib/python3.8/site-packages/pynytimes-0.7.0-py3.8.egg/pynytimes/api.py:766: UserWarning: Asking for a lot of results, because of rate limits it can take a while.

# %%
test_df_12.tail(1)
# Out:
#                                              abstract  \
# 99  Shoppers spent more this holiday season than a...
#
#                                               web_url  \
# 99  https://www.nytimes.com/2010/12/28/business/28...
#
#                                               snippet  \
# 99  Shoppers spent more this holiday season than a...
#
#                                        lead_paragraph              source  \
# 99  Americans are splurging as though it’s 2007 ag...  The New York Times
#
#                                            multimedia  \
# 99  [{'rank': 0, 'subtype': 'jumbo', 'caption': No...
#
#                                              headline  \
# 99  {'main': 'Retail Sales Rebound, Beating Foreca...
#
#                                              keywords  \
# 99  [{'name': 'subject', 'value': 'Shopping and Re...
#
#                     pub_date document_type news_desk  section_name  \
# 99 2010-12-27 23:38:59+00:00       article  Business  Business Day
#
#    subsection_name                                             byline  \
# 99             NaN  {'original': 'By Stephanie Clifford', 'person'...
#
#    type_of_material                                                _id  \
# 99             News  nyt://article/54045c51-f140-5919-94d8-658467bb...
#
#     word_count                                                uri  \
# 99        1040  nyt://article/54045c51-f140-5919-94d8-658467bb...
#
#    print_section print_page
# 99             B          1

# %%
test_df_11.tail(1)
# Out:
#                                               abstract  \
# 299  The bank agreed to pay more than $2.5 billion ...
#
#                                                web_url  \
# 299  https://www.nytimes.com/2011/01/04/business/04...
#
#                                                snippet  \
# 299  The bank agreed to pay more than $2.5 billion ...
#
#                                         lead_paragraph              source  \
# 299  Bank of America announced on Monday that it ha...  The New York Times
#
#     multimedia                                           headline  \
# 299         []  {'main': 'Bank of America Buys Back $2.5 Billi...
#
#                                               keywords  \
# 299  [{'name': 'subject', 'value': 'Company Reports...
#
#                      pub_date document_type news_desk  section_name  \
# 299 2011-01-03 12:45:25+00:00       article  Business  Business Day
#
#                                                 byline type_of_material  \
# 299  {'original': 'By Ben Protess and Eric Dash', '...             News
#
#                                                    _id  word_count  \
# 299  nyt://article/9b605a3b-41dc-5087-a860-b5ab5f90...         714
#
#                                                    uri subsection_name  \
# 299  nyt://article/9b605a3b-41dc-5087-a860-b5ab5f90...             NaN
#
#     print_section print_page
# 299             B          3

# %%
test_df_10.tail(1)
# Out:
#                                                abstract  \
# 1799  The solar permit process varies widely from mu...
#
#                                                 web_url  \
# 1799  https://www.nytimes.com/2011/01/20/business/en...
#
#                                                 snippet  \
# 1799  The solar permit process varies widely from mu...
#
#                                          lead_paragraph print_section  \
# 1799  Ken Button, the president of Verengo Solar Plu...             B
#
#      print_page              source  \
# 1799          1  The New York Times
#
#                                              multimedia  \
# 1799  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
#
#                                                headline  \
# 1799  {'main': 'Solar Firms Frustrated by Permits', ...
#
#                                                keywords  \
# 1799  [{'name': 'subject', 'value': 'Solar Energy', ...
#
#                       pub_date document_type news_desk  section_name  \
# 1799 2011-01-20 01:54:23+00:00       article  Business  Business Day
#
#             subsection_name  \
# 1799  Energy & Environment
#
#                                                  byline type_of_material  \
# 1799  {'original': 'By Tom Zeller Jr', 'person': [{'...             News
#
#                                                     _id  word_count  \
# 1799  nyt://article/aedf8f78-9c01-5b8c-8c18-a20faacb...        1104
#
#                                                     uri
# 1799  nyt://article/aedf8f78-9c01-5b8c-8c18-a20faacb...

# %%
test_df_9.tail(1)
# Out:
#                                                abstract  \
# 1799  The cases question whether the Madoff firm’s t...
#
#                                                 web_url  \
# 1799  https://www.nytimes.com/2011/05/06/business/06...
#
#                                                 snippet  \
# 1799  The cases question whether the Madoff firm’s t...
#
#                                          lead_paragraph print_section  \
# 1799  Two cases tied to efforts to liquidate Bernard...             B
#
#      print_page              source  \
# 1799          9  The New York Times
#
#                                              multimedia  \
# 1799  [{'rank': 0, 'subtype': 'blog480', 'caption': ...
#
#                                                headline  \
# 1799  {'main': 'Two Madoff Cases Reach Federal Court...
#
#                                                keywords  \
# 1799  [{'name': 'persons', 'value': 'Picard, Irving ...
#
#                       pub_date document_type news_desk  section_name  \
# 1799 2011-05-06 01:21:47+00:00       article  Business  Business Day
#
#                                                  byline type_of_material  \
# 1799  {'original': 'By Bloomberg News', 'person': [{...             News
#
#                                                     _id  word_count  \
# 1799  nyt://article/bf9d3251-28e6-510f-8dce-155126ba...         409
#
#                                                     uri subsection_name
# 1799  nyt://article/bf9d3251-28e6-510f-8dce-155126ba...             NaN

# %%
test_df_8.tail()
# Out:
#                                                abstract  \
# 1795  Kathleen Barnes joined Kelliher Samets Volk, B...
# 1796  Red Lobster’s new campaign connects restaurant...
# 1797  In their first joint development project, the ...
# 1798           Highlights from the DealBook newsletter.
# 1799  A slump in Germany and France raises the possi...
#
#                                                 web_url  \
# 1795  https://www.nytimes.com/2011/08/22/business/me...
# 1796  https://www.nytimes.com/2011/08/22/business/me...
# 1797  https://www.nytimes.com/2011/08/23/business/fo...
# 1798  https://dealbook.nytimes.com/2011/08/22/mornin...
# 1799  https://www.nytimes.com/2011/08/23/business/gl...
#
#                                                 snippet  \
# 1795  Kathleen Barnes joined Kelliher Samets Volk, B...
# 1796  Red Lobster’s new campaign connects restaurant...
# 1797  In their first joint development project, the ...
# 1798           Highlights from the DealBook newsletter.
# 1799  A slump in Germany and France raises the possi...
#
#                                          lead_paragraph print_section  \
# 1795  Kathleen Barnes joined Kelliher Samets Volk, B...           NaN
# 1796                                        Q. (Reader)           NaN
# 1797  DEARBORN, Mich. — Ford Motor Company and Toyot...             B
# 1798  Star Analysts Are Back (No Autographs, Please)...           NaN
# 1799  BERLIN — It is not hard to come up with reason...           NaN
#
#      print_page                        source  \
# 1795        NaN            The New York Times
# 1796        NaN            The New York Times
# 1797          3            The New York Times
# 1798        NaN            The New York Times
# 1799        NaN  International Herald Tribune
#
#                                              multimedia  \
# 1795                                                 []
# 1796  [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# 1797  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1798                                                 []
# 1799                                                 []
#
#                                                headline  \
# 1795  {'main': 'Accounts and People of Note in the A...
# 1796  {'main': 'Q. and A. With Stuart Elliott', 'kic...
# 1797  {'main': 'Ford and Toyota to Work Together on ...
# 1798  {'main': 'Morning Take-Out', 'kicker': 'DealBo...
# 1799  {'main': 'Last Bulwark of Euro Could Be Totter...
#
#                                                keywords  \
# 1795  [{'name': 'subject', 'value': 'Appointments an...
# 1796  [{'name': 'subject', 'value': 'Advertising and...
# 1797  [{'name': 'organizations', 'value': 'Ford Moto...
# 1798                                                 []
# 1799                                                 []
#
#                       pub_date document_type news_desk  section_name  \
# 1795 2011-08-22 17:50:31+00:00       article  Business  Business Day
# 1796 2011-08-22 17:50:29+00:00       article  Business  Business Day
# 1797 2011-08-22 16:51:26+00:00       article  Business  Business Day
# 1798 2011-08-22 13:57:58+00:00       article  Business  Business Day
# 1799 2011-08-22 12:55:09+00:00       article  Business  Business Day
#
#                                                  byline type_of_material  \
# 1795  {'original': 'By The New York Times', 'person'...             News
# 1796  {'original': None, 'person': [], 'organization...             News
# 1797  {'original': 'By Nick Bunkley', 'person': [{'f...             News
# 1798  {'original': 'By Dealbook', 'person': [{'first...             News
# 1799  {'original': 'By NOAH BARKIN | REUTERS', 'pers...             News
#
#                                                     _id  word_count  \
# 1795  nyt://article/57a87450-005d-53a3-927e-2e77cda2...        1222
# 1796  nyt://article/a7d0366d-7411-5eed-b1e4-63166bf3...         238
# 1797  nyt://article/791bab91-f51a-528d-9909-267edd07...         570
# 1798  nyt://article/a14293a8-97a9-56c2-8982-26af6a74...        1899
# 1799  nyt://article/85c25116-b281-5966-a98c-f64c1be5...         732
#
#                                                     uri  subsection_name
# 1795  nyt://article/57a87450-005d-53a3-927e-2e77cda2...            Media
# 1796  nyt://article/a7d0366d-7411-5eed-b1e4-63166bf3...            Media
# 1797  nyt://article/791bab91-f51a-528d-9909-267edd07...              NaN
# 1798  nyt://article/a14293a8-97a9-56c2-8982-26af6a74...              NaN
# 1799  nyt://article/85c25116-b281-5966-a98c-f64c1be5...  Global Business

# %%
test_df_7.tail(1)
# Out:
#                                                abstract  \
# 1799  A group dedicated to preventing suicide among ...
#
#                                                 web_url  \
# 1799  https://www.nytimes.com/2011/12/05/business/me...
#
#                                                 snippet  \
# 1799  A group dedicated to preventing suicide among ...
#
#                                          lead_paragraph print_section  \
# 1799  An organization that provides young Americans ...           NaN
#
#      print_page              source  \
# 1799        NaN  The New York Times
#
#                                              multimedia  \
# 1799  [{'rank': 0, 'subtype': 'jumbo', 'caption': No...
#
#                                                headline  \
# 1799  {'main': 'New Endeavor for Trevor Project', 'k...
#
#                                                keywords  \
# 1799  [{'name': 'subject', 'value': 'Advertising and...
#
#                       pub_date document_type news_desk  section_name  \
# 1799 2011-12-05 18:38:52+00:00       article  Business  Business Day
#
#                                                  byline type_of_material  \
# 1799  {'original': 'By Stuart Elliott', 'person': [{...             News
#
#                                                     _id  word_count  \
# 1799  nyt://article/80e1d99f-73e3-5582-bc94-a726829c...        1320
#
#                                                     uri subsection_name
# 1799  nyt://article/80e1d99f-73e3-5582-bc94-a726829c...           Media

# %%
test_df_6.tail(1)
# Out:
#                                                abstract  \
# 1799  Anniversary campaigns are part of a trend that...
#
#                                                 web_url  \
# 1799  https://www.nytimes.com/2012/04/10/business/me...
#
#                                                 snippet  \
# 1799  Anniversary campaigns are part of a trend that...
#
#                                          lead_paragraph print_section  \
# 1799  IF Madison Avenue had its own hit parade or Ho...             B
#
#      print_page              source  \
# 1799          2  The New York Times
#
#                                              multimedia  \
# 1799  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
#
#                                                headline  \
# 1799  {'main': 'Brands Cheer Their Virtues With Anni...
#
#                                                keywords  \
# 1799  [{'name': 'subject', 'value': 'Emotions', 'ran...
#
#                       pub_date document_type news_desk  section_name  \
# 1799 2012-04-10 00:03:23+00:00       article  Business  Business Day
#
#      subsection_name                                             byline  \
# 1799           Media  {'original': 'By Stuart Elliott', 'person': [{...
#
#      type_of_material                                                _id  \
# 1799             News  nyt://article/0bb37ae3-9a7c-5f55-9999-3277c56b...
#
#       word_count                                                uri
# 1799         921  nyt://article/0bb37ae3-9a7c-5f55-9999-3277c56b...

# %%
test_df_5.tail(1)
# Out:
#                                                abstract  \
# 1799  Sonu Shivdasani is chief executive of Soneva, ...
#
#                                                 web_url  \
# 1799  https://www.nytimes.com/2012/08/20/business/gl...
#
#                                                 snippet  \
# 1799  Sonu Shivdasani is chief executive of Soneva, ...
#
#                                          lead_paragraph print_section  \
# 1799   Sonu Shivdasani  is chief executive of Soneva...           NaN
#
#      print_page                        source multimedia  \
# 1799        NaN  International Herald Tribune         []
#
#                                                headline  \
# 1799  {'main': 'Language Can Be the Key to Results',...
#
#                                                keywords  \
# 1799  [{'name': 'subject', 'value': 'Executives and ...
#
#                       pub_date document_type news_desk  section_name  \
# 1799 2012-08-19 11:21:08+00:00       article  Business  Business Day
#
#       subsection_name                                             byline  \
# 1799  Global Business  {'original': 'By Sonia Kolesnikov-Jessop', 'pe...
#
#      type_of_material                                                _id  \
# 1799             News  nyt://article/4dc1d4e2-0597-5b71-acdf-b0cb0c48...
#
#       word_count                                                uri
# 1799         982  nyt://article/4dc1d4e2-0597-5b71-acdf-b0cb0c48...

# %%
test_df_4.tail(2)
# Out:
#                                                abstract  \
# 1798  Wall Street ended its first day of trading in ...
# 1799  Task lists, special calendars and social apps ...
#
#                                                 web_url  \
# 1798  https://www.nytimes.com/2013/01/03/business/da...
# 1799  https://www.nytimes.com/2013/01/03/technology/...
#
#                                                 snippet  \
# 1798  Wall Street ended its first day of trading in ...
# 1799  Task lists, special calendars and social apps ...
#
#                                          lead_paragraph print_section  \
# 1798  Wall Street cheered an agreement that ended th...             B
# 1799  I’ve never really made New Year’s resolutions ...             B
#
#      print_page              source  \
# 1798          9  The New York Times
# 1799          6  The New York Times
#
#                                              multimedia  \
# 1798  [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# 1799  [{'rank': 0, 'subtype': 'wide', 'caption': Non...
#
#                                                headline  \
# 1798  {'main': 'Big Gains on Wall Street After the F...
# 1799  {'main': 'Tech Reminders for Keeping Those New...
#
#                                                keywords  \
# 1798  [{'name': 'persons', 'value': 'Popper, Nathani...
# 1799  [{'name': 'subject', 'value': 'Mobile Applicat...
#
#                       pub_date document_type news_desk  section_name  \
# 1798 2013-01-02 22:43:37+00:00       article  Business  Business Day
# 1799 2013-01-02 21:09:44+00:00       article  Business    Technology
#
#                                                  byline type_of_material  \
# 1798  {'original': 'By Nathaniel Popper', 'person': ...             News
# 1799  {'original': 'By Kit Eaton', 'person': [{'firs...             News
#
#                                                     _id  word_count  \
# 1798  nyt://article/45e47cbc-692b-5ebf-aecb-8945f135...         854
# 1799  nyt://article/7b848e45-76cd-5fba-b60e-d7c99553...         823
#
#                                                     uri subsection_name
# 1798  nyt://article/45e47cbc-692b-5ebf-aecb-8945f135...             NaN
# 1799  nyt://article/7b848e45-76cd-5fba-b60e-d7c99553...   Personal Tech

# %%
test_df_3.tail()
# Out:
#                                                abstract  \
# 1795  British business, which has a vital interest i...
# 1796  A new analysis finds the current Supreme Court...
# 1797  College graduates are the only group that has ...
# 1798  The drug pairs Merck’s Zetia, which lowers low...
# 1799  Activist shareholders had called for the 78-ye...
#
#                                                 web_url  \
# 1795  https://www.nytimes.com/2013/05/06/business/gl...
# 1796  https://www.nytimes.com/2013/05/05/business/pr...
# 1797  https://www.nytimes.com/2013/05/04/business/co...
# 1798  https://www.nytimes.com/2013/05/04/business/fd...
# 1799  https://www.nytimes.com/2013/05/04/business/oc...
#
#                                                 snippet  \
# 1795  British business, which has a vital interest i...
# 1796  A new analysis finds the current Supreme Court...
# 1797  College graduates are the only group that has ...
# 1798  The drug pairs Merck’s Zetia, which lowers low...
# 1799  Activist shareholders had called for the 78-ye...
#
#                                          lead_paragraph print_section  \
# 1795  The UK Independence Party will not come close ...           NaN
# 1796  NOT long after 10 a.m. on March 27, a restless...            BU
# 1797  Is college worth it? Given the growing price t...             B
# 1798  The Food and Drug Administration approved on F...             B
# 1799  Conceding to a shareholder revolt, Occidental ...             B
#
#      print_page                        source  \
# 1795        NaN  International Herald Tribune
# 1796          1            The New York Times
# 1797          1            The New York Times
# 1798          4            The New York Times
# 1799          4            The New York Times
#
#                                              multimedia  \
# 1795                                                 []
# 1796  [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# 1797  [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# 1798                                                 []
# 1799  [{'rank': 0, 'subtype': 'wide', 'caption': Non...
#
#                                                headline  \
# 1795  {'main': 'Britain’s Conservatives Squeezed by ...
# 1796  {'main': 'Corporations Find a Friend in the Su...
# 1797  {'main': 'College Graduates Fare Well in Jobs ...
# 1798  {'main': 'Drug to Cut Cholesterol Is Approved ...
# 1799  {'main': 'Occidental Chairman Agrees to Step D...
#
#                                                keywords  \
# 1795  [{'name': 'glocations', 'value': 'Great Britai...
# 1796  [{'name': 'organizations', 'value': 'Supreme C...
# 1797  [{'name': 'subject', 'value': 'Colleges and Un...
# 1798  [{'name': 'persons', 'value': 'Thomas, Katie',...
# 1799  [{'name': 'persons', 'value': 'Krauss, Cliffor...
#
#                       pub_date document_type news_desk  section_name  \
# 1795 2013-05-05 09:13:48+00:00       article  Business  Business Day
# 1796 2013-05-04 21:52:10+00:00       article  Business  Business Day
# 1797 2013-05-04 01:09:48+00:00       article  Business  Business Day
# 1798 2013-05-04 00:49:50+00:00       article  Business  Business Day
# 1799 2013-05-03 21:06:49+00:00       article  Business  Business Day
#
#                                                  byline type_of_material  \
# 1795  {'original': 'By Hugo Dixon | Reuters', 'perso...             News
# 1796  {'original': 'By Adam Liptak', 'person': [{'fi...             News
# 1797  {'original': 'By Catherine Rampell', 'person':...             News
# 1798  {'original': 'By Katie Thomas', 'person': [{'f...             News
# 1799  {'original': 'By Clifford Krauss', 'person': [...             News
#
#                                                     _id  word_count  \
# 1795  nyt://article/1288df31-e69e-5339-8e56-eb989d0a...         937
# 1796  nyt://article/706e0db3-3cdf-5d1a-b213-59ec4132...        2652
# 1797  nyt://article/d9414fa0-36cb-56e9-8e10-3115f335...        1014
# 1798  nyt://article/652e5389-f054-5e72-9f42-f3488c00...         474
# 1799  nyt://article/5fce7673-194d-5dc4-83b6-6b69f7bb...         702
#
#                                                     uri  subsection_name
# 1795  nyt://article/1288df31-e69e-5339-8e56-eb989d0a...  Global Business
# 1796  nyt://article/706e0db3-3cdf-5d1a-b213-59ec4132...              NaN
# 1797  nyt://article/d9414fa0-36cb-56e9-8e10-3115f335...              NaN
# 1798  nyt://article/652e5389-f054-5e72-9f42-f3488c00...              NaN
# 1799  nyt://article/5fce7673-194d-5dc4-83b6-6b69f7bb...              NaN

# %%
test_df_2
# Out:
#                                               abstract  \
# 0    Even with the partial federal shutdown, new-ca...
# 1    With Sebastian Vettel crowned this year’s Form...
# 2    A year after Hurricane Sandy flooded Brooklyn ...
# 3    When employment statistics are adjusted to acc...
# 4    The Federal Communications Commission has prop...
# ..                                                 ...
# 995  The Group of 20 summit meeting is expected to ...
# 996  A federal court in Washington blocked one serv...
# 997  Europe said it would pare back its law in exch...
# 998  Line, which has hundreds of millions of users ...
# 999  David Blech, who was once biotechnology’s top ...
#
#                                                web_url  \
# 0    https://www.nytimes.com/2013/11/02/business/us...
# 1    https://www.nytimes.com/2013/11/02/automobiles...
# 2    https://www.nytimes.com/2013/11/01/automobiles...
# 3    https://www.nytimes.com/2013/11/02/business/ec...
# 4    https://www.nytimes.com/2013/11/02/business/me...
# ..                                                 ...
# 995  https://www.nytimes.com/2013/09/06/business/gl...
# 996  https://www.nytimes.com/2013/09/06/business/me...
# 997  https://www.nytimes.com/2013/09/06/business/gl...
# 998  https://www.nytimes.com/2013/09/06/technology/...
# 999  https://www.nytimes.com/2013/09/06/business/da...
#
#                                                snippet  \
# 0    Even with the partial federal shutdown, new-ca...
# 1    With Sebastian Vettel crowned this year’s Form...
# 2    A year after Hurricane Sandy flooded Brooklyn ...
# 3    When employment statistics are adjusted to acc...
# 4    The Federal Communications Commission has prop...
# ..                                                 ...
# 995  The Group of 20 summit meeting is expected to ...
# 996  A federal court in Washington blocked one serv...
# 997  Europe said it would pare back its law in exch...
# 998  Line, which has hundreds of millions of users ...
# 999  David Blech, who was once biotechnology’s top ...
#
#                                         lead_paragraph print_section  \
# 0    DETROIT — The tempo for new-car sales in the U...             B
# 1    Sunday’s Grand Prix of Abu Dhabi —– 17th of th...           NaN
# 2    When you think of waterfront property, beach h...           NaN
# 3    THE unemployment rate has fallen by nearly thr...             B
# 4    WASHINGTON — The Federal Communications Commis...             B
# ..                                                 ...           ...
# 995  MOSCOW — Many of the leaders of the world’s ri...             B
# 996  For the first time in nearly a year, the natio...           NaN
# 997  BRUSSELS — Seeking to end years of acrimony, t...             B
# 998  TOKYO — Traditionally, Japanese bow when greet...             B
# 999  He was once hailed as the king of biotechnolog...             B
#
#     print_page              source  \
# 0            2  The New York Times
# 1          NaN  The New York Times
# 2          NaN  The New York Times
# 3            3  The New York Times
# 4            1  The New York Times
# ..         ...                 ...
# 995          1  The New York Times
# 996        NaN  The New York Times
# 997          3  The New York Times
# 998          2  The New York Times
# 999          1  The New York Times
#
#                                             multimedia  \
# 0                                                   []
# 1    [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# 2    [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# 3                                                   []
# 4    [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# ..                                                 ...
# 995  [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# 996                                                 []
# 997                                                 []
# 998  [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# 999  [{'rank': 0, 'subtype': 'wide', 'caption': Non...
#
#                                               headline  \
# 0    {'main': 'Big Gains for Auto Sales Despite a G...
# 1    {'main': 'For Vettel, No Pressure in Abu Dhabi...
# 2    {'main': 'Brooklyn Motor Works: From Underwate...
# 3    {'main': 'Changes in Labor Force Mask Gains in...
# 4    {'main': 'F.C.C. Plans Sweeping Changes to Bol...
# ..                                                 ...
# 995  {'main': 'Plan at G-20 Is to Tighten Global Ru...
# 996  {'main': 'Networks Get a Victory in Court Over...
# 997  {'main': 'Europe Offers U.S. a Deal, Hoping fo...
# 998  {'main': 'A Japanese Social App Contacts New S...
# 999  {'main': 'A Biotech King, Dethroned', 'kicker'...
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Automobiles', '...
# 1    [{'name': 'subject', 'value': 'Automobiles', '...
# 2    [{'name': 'subject', 'value': 'Hurricane Sandy...
# 3    [{'name': 'subject', 'value': 'United States E...
# 4    [{'name': 'subject', 'value': 'Regulation and ...
# ..                                                 ...
# 995  [{'name': 'organizations', 'value': 'Group of ...
# 996  [{'name': 'subject', 'value': 'Suits and Litig...
# 997  [{'name': 'persons', 'value': 'Kanter, James',...
# 998  [{'name': 'persons', 'value': 'Pfanner, Eric',...
# 999  [{'name': 'persons', 'value': 'Blech, David', ...
#
#                      pub_date document_type news_desk  section_name  \
# 0   2013-11-01 20:35:16+00:00       article  Business  Business Day
# 1   2013-11-01 19:00:07+00:00       article  Business   Automobiles
# 2   2013-11-01 18:42:29+00:00       article  Business   Automobiles
# 3   2013-11-01 18:41:44+00:00       article  Business  Business Day
# 4   2013-11-01 18:19:19+00:00       article  Business  Business Day
# ..                        ...           ...       ...           ...
# 995 2013-09-06 01:18:43+00:00       article  Business  Business Day
# 996 2013-09-06 01:09:06+00:00       article  Business  Business Day
# 997 2013-09-06 01:02:11+00:00       article  Business  Business Day
# 998 2013-09-06 00:56:02+00:00       article  Business    Technology
# 999 2013-09-06 00:38:01+00:00       article  Business  Business Day
#
#                                                 byline type_of_material  \
# 0    {'original': 'By Jaclyn Trop', 'person': [{'fi...             News
# 1    {'original': 'By Leo Levine', 'person': [{'fir...             News
# 2    {'original': 'By Benjamin Preston', 'person': ...             News
# 3    {'original': 'By Floyd Norris', 'person': [{'f...             News
# 4    {'original': 'By Edward Wyatt', 'person': [{'f...             News
# ..                                                 ...              ...
# 995  {'original': 'By Andrew E. Kramer', 'person': ...             News
# 996  {'original': 'By Brian Stelter', 'person': [{'...             News
# 997  {'original': 'By James Kanter', 'person': [{'f...             News
# 998  {'original': 'By Eric Pfanner', 'person': [{'f...             News
# 999  {'original': 'By Andrew Pollack', 'person': [{...             News
#
#                                                    _id  word_count  \
# 0    nyt://article/abace18d-0cb4-5cc5-9e18-ad35d89a...         686
# 1    nyt://article/b9835a8c-30b6-59f8-acee-d2c8ddb3...         645
# 2    nyt://article/ba0a0686-78f6-5c98-9190-ad08d911...         902
# 3    nyt://article/d43c1560-39c4-5ee9-b7aa-22cf5175...         714
# 4    nyt://article/bd83811d-72f2-5932-80fa-495a546b...         767
# ..                                                 ...         ...
# 995  nyt://article/f4b0429f-f95b-51d1-9cb6-5ea2ab25...         913
# 996  nyt://article/e63b2aff-5130-5099-87ae-64abbefc...         604
# 997  nyt://article/99a00659-0fa8-5b51-9a2e-61c27523...         911
# 998  nyt://article/ec89a325-e723-56cf-9461-bdd20ef9...        1203
# 999  nyt://article/8ca86cdf-63f0-50db-b217-d24086dd...        1433
#
#                                                    uri  subsection_name
# 0    nyt://article/abace18d-0cb4-5cc5-9e18-ad35d89a...              NaN
# 1    nyt://article/b9835a8c-30b6-59f8-acee-d2c8ddb3...              NaN
# 2    nyt://article/ba0a0686-78f6-5c98-9190-ad08d911...              NaN
# 3    nyt://article/d43c1560-39c4-5ee9-b7aa-22cf5175...          Economy
# 4    nyt://article/bd83811d-72f2-5932-80fa-495a546b...            Media
# ..                                                 ...              ...
# 995  nyt://article/f4b0429f-f95b-51d1-9cb6-5ea2ab25...  Global Business
# 996  nyt://article/e63b2aff-5130-5099-87ae-64abbefc...            Media
# 997  nyt://article/99a00659-0fa8-5b51-9a2e-61c27523...  Global Business
# 998  nyt://article/ec89a325-e723-56cf-9461-bdd20ef9...              NaN
# 999  nyt://article/8ca86cdf-63f0-50db-b217-d24086dd...              NaN
#
# [1000 rows x 20 columns]

# %%
test_df
# Out:
#                                               abstract  \
# 0    Judge Edward R. Korman of the Eastern District...
# 1    Mr. Ravitch, 80, is a lawyer who for several y...
# 2    City officials hope to bring a disparate jumbl...
# 3    College dormitories are booming in Manhattan, ...
# 4    Pure, a British electronics manufacturer, make...
# ..                                                 ...
# 995  The change, expected before the end of the yea...
# 996  Jeep’s soft pet carrier offers pet owners a sa...
# 997  Many of the growth plans laid out in June lack...
# 998  The cable company lost 306,000 television subs...
# 999  The company said the results were positive bec...
#
#                                                web_url  \
# 0    https://www.nytimes.com/2014/01/01/business/ju...
# 1    https://www.nytimes.com/2014/01/01/realestate/...
# 2    https://www.nytimes.com/2014/01/01/realestate/...
# 3    https://www.nytimes.com/2014/01/01/realestate/...
# 4    https://www.nytimes.com/2014/01/02/technology/...
# ..                                                 ...
# 995  https://www.nytimes.com/2013/11/01/business/pa...
# 996  https://www.nytimes.com/2013/10/31/automobiles...
# 997  https://www.nytimes.com/2013/11/01/business/in...
# 998  https://www.nytimes.com/2013/11/01/business/me...
# 999  https://www.nytimes.com/2013/11/01/business/me...
#
#                                                snippet  \
# 0    Judge Edward R. Korman of the Eastern District...
# 1    Mr. Ravitch, 80, is a lawyer who for several y...
# 2    City officials hope to bring a disparate jumbl...
# 3    College dormitories are booming in Manhattan, ...
# 4    Pure, a British electronics manufacturer, make...
# ..                                                 ...
# 995  The change, expected before the end of the yea...
# 996  Jeep’s soft pet carrier offers pet owners a sa...
# 997  Many of the growth plans laid out in June lack...
# 998  The cable company lost 306,000 television subs...
# 999  The company said the results were positive bec...
#
#                                         lead_paragraph print_section  \
# 0    The government’s right to search travelers’ el...             B
# 1    Mr. Ravitch, 80, is a lawyer who for several y...             B
# 2    PHILADELPHIA — On a desolate North Philadelphi...             B
# 3    Manhattan may be a bit large to be considered ...             B
# 4    Two of the biggest tech trends this year were ...           NaN
# ..                                                 ...           ...
# 995  WASHINGTON — The days of airline passengers be...             B
# 996  Just about anyone with a large dog can appreci...            AU
# 997  HONG KONG — Nearly a year after the Japanese b...             B
# 998  The CBS blackout in homes with Time Warner Cab...             B
# 999  The New York Times Company reported a quarterl...             B
#
#     print_page              source  \
# 0            3  The New York Times
# 1            5  The New York Times
# 2            1  The New York Times
# 3            4  The New York Times
# 4          NaN  The New York Times
# ..         ...                 ...
# 995          1  The New York Times
# 996          4  The New York Times
# 997          8  The New York Times
# 998          1  The New York Times
# 999          7  The New York Times
#
#                                             multimedia  \
# 0    [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# 1    [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# 2    [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# 3    [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# 4    [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# ..                                                 ...
# 995                                                 []
# 996  [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# 997  [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# 998  [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# 999                                                 []
#
#                                               headline  \
# 0    {'main': 'District Judge Upholds Government’s ...
# 1    {'main': 'Richard Ravitch', 'kicker': None, 'c...
# 2    {'main': 'Philadelphia Forges Plan to Rebuild ...
# 3    {'main': 'Where 600 College Students Live Abov...
# 4    {'main': 'The Marriage of Wireless Speaker and...
# ..                                                 ...
# 995  {'main': 'F.A.A. Moves to Ease Electronics Ban...
# 996  {'main': 'A Doggie Bag for Your Jeep', 'kicker...
# 997  {'main': 'After a Run of Growth, Concern Over ...
# 998  {'main': 'Time Warner Left Bruised in Fee Batt...
# 999  {'main': 'Times Co. Posts a Loss, Hurt by Sale...
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Search and Seiz...
# 1    [{'name': 'persons', 'value': 'Ravitch, Richar...
# 2    [{'name': 'persons', 'value': 'Hurdle, Jon', '...
# 3    [{'name': 'persons', 'value': 'Hughes, C J', '...
# 4    [{'name': 'subject', 'value': 'Speakers (Audio...
# ..                                                 ...
# 995  [{'name': 'subject', 'value': 'Airlines and Ai...
# 996  [{'name': 'subject', 'value': 'Automobiles', '...
# 997  [{'name': 'glocations', 'value': 'Japan', 'ran...
# 998  [{'name': 'persons', 'value': 'Stelter, Brian'...
# 999  [{'name': 'persons', 'value': 'Haughney, Chris...
#
#                      pub_date document_type news_desk  section_name  \
# 0   2013-12-31 23:48:51+00:00       article  Business  Business Day
# 1   2013-12-31 22:56:18+00:00       article  Business   Real Estate
# 2   2013-12-31 22:48:35+00:00       article  Business   Real Estate
# 3   2013-12-31 21:36:51+00:00       article  Business   Real Estate
# 4   2013-12-31 19:37:42+00:00       article  Business    Technology
# ..                        ...           ...       ...           ...
# 995 2013-10-31 15:06:07+00:00       article  Business  Business Day
# 996 2013-10-31 14:00:06+00:00       article  Business   Automobiles
# 997 2013-10-31 13:51:58+00:00       article  Business  Business Day
# 998 2013-10-31 12:39:13+00:00       article  Business  Business Day
# 999 2013-10-31 12:35:00+00:00       article  Business  Business Day
#
#                                                 byline type_of_material  \
# 0    {'original': 'By Susan Stellin', 'person': [{'...             News
# 1    {'original': 'By Vivian Marino', 'person': [{'...        Interview
# 2    {'original': 'By Jon Hurdle', 'person': [{'fir...             News
# 3    {'original': 'By C. J. Hughes', 'person': [{'f...             News
# 4    {'original': 'By Gregory Schmidt', 'person': [...             News
# ..                                                 ...              ...
# 995  {'original': 'By Matthew L. Wald', 'person': [...             News
# 996  {'original': 'By Benjamin Preston', 'person': ...             News
# 997  {'original': 'By Bettina Wassener', 'person': ...             News
# 998  {'original': 'By Brian Stelter', 'person': [{'...             News
# 999  {'original': 'By Christine Haughney', 'person'...             News
#
#                                                    _id  word_count  \
# 0    nyt://article/2b1e823c-a372-5db3-ae95-86f20e4a...         741
# 1    nyt://article/9ae83f7d-6bd4-5d77-88d2-329b0527...         885
# 2    nyt://article/ff1041e2-7171-5842-88fb-f52c5f1f...        1199
# 3    nyt://article/525c0c66-ca09-5e8f-8609-b7523d73...        1180
# 4    nyt://article/ac9fb65f-e884-50b8-84f0-20c7e52f...         368
# ..                                                 ...         ...
# 995  nyt://article/0d9325bc-05da-55d3-ac46-1374aa68...         968
# 996  nyt://article/0dfd53b6-1053-554c-9b9a-9e4ad3fb...         335
# 997  nyt://article/8a2723f0-70d8-5b4b-88e5-0a2f03c2...         778
# 998  nyt://article/68cbde2a-6933-5aba-9107-9e8ac6a4...         958
# 999  nyt://article/be9facbc-1911-5936-af4f-40419f4e...         708
#
#                                                    uri         subsection_name
# 0    nyt://article/2b1e823c-a372-5db3-ae95-86f20e4a...                     NaN
# 1    nyt://article/9ae83f7d-6bd4-5d77-88d2-329b0527...  Commercial Real Estate
# 2    nyt://article/ff1041e2-7171-5842-88fb-f52c5f1f...  Commercial Real Estate
# 3    nyt://article/525c0c66-ca09-5e8f-8609-b7523d73...  Commercial Real Estate
# 4    nyt://article/ac9fb65f-e884-50b8-84f0-20c7e52f...           Personal Tech
# ..                                                 ...                     ...
# 995  nyt://article/0d9325bc-05da-55d3-ac46-1374aa68...                     NaN
# 996  nyt://article/0dfd53b6-1053-554c-9b9a-9e4ad3fb...                     NaN
# 997  nyt://article/8a2723f0-70d8-5b4b-88e5-0a2f03c2...  International Business
# 998  nyt://article/68cbde2a-6933-5aba-9107-9e8ac6a4...                   Media
# 999  nyt://article/be9facbc-1911-5936-af4f-40419f4e...                   Media
#
# [1000 rows x 20 columns]

# %%
master_df = pd.concat([test_df, test_df_2,test_df_3, test_df_4,test_df_5,test_df_6,test_df_7,test_df_8,test_df_9,test_df_10, test_df_11, test_df_12])
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16800 entries, 0 to 99
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   abstract          16800 non-null  object
#  1   web_url           16800 non-null  object
#  2   snippet           16800 non-null  object
#  3   lead_paragraph    16800 non-null  object
#  4   print_section     13467 non-null  object
#  5   print_page        13467 non-null  object
#  6   source            16800 non-null  object
#  7   multimedia        16800 non-null  object
#  8   headline          16800 non-null  object
#  9   keywords          16800 non-null  object
#  10  pub_date          16800 non-null  datetime64[ns, UTC]
#  11  document_type     16800 non-null  object
#  12  news_desk         16800 non-null  object
#  13  section_name      16800 non-null  object
#  14  byline            16800 non-null  object
#  15  type_of_material  16800 non-null  object
#  16  _id               16800 non-null  object
#  17  word_count        16800 non-null  int64
#  18  uri               16800 non-null  object
#  19  subsection_name   9434 non-null   object
# dtypes: datetime64[ns, UTC](1), int64(1), object(18)
# memory usage: 2.7+ MB

# %%
master_df.to_csv('data_2011-2013_PL.csv')
